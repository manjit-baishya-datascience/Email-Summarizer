# %% [markdown]
# # **Downloading datasets from `HuggingFace`**
# ---

# %% [markdown]
# ## **Dataset 1 - `argilla/news-summary`**

# %%
# %pip install huggingface_hub

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="argilla/news-summary",   
    repo_type="dataset",
    local_dir="../datasets/01 argilla news-summary"            
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# '/media/manjit/Project Drive/Email Summarizer/datasets/01 argilla news-summary'

# %% [markdown]
# ## **Dataset 2 - `EdinburghNLP/xsum`**

# %%
snapshot_download(
    repo_id="EdinburghNLP/xsum",   
    repo_type="dataset",
    local_dir="../datasets/02 EdinburghNLP xsum"            
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# '/media/manjit/Project Drive/Email Summarizer/datasets/02 EdinburghNLP xsum'

# %% [markdown]
# ## **Dataset 3 - `koushik7198/Samsung-samsum_processed`**

# %%
snapshot_download(
    repo_id="koushik7198/Samsung-samsum_processed",   
    repo_type="dataset",
    local_dir="../datasets/03 koushik7198 Samsung-samsum_processed"            
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# '/media/manjit/Project Drive/Email Summarizer/datasets/03 koushik7198 Samsung-samsum_processed'

# %% [markdown]
# ## **Dataset 4 - `argilla/FinePersonas-Conversations-Email-Summaries`**

# %%
snapshot_download(
    repo_id="argilla/FinePersonas-Conversations-Email-Summaries",   
    repo_type="dataset",
    local_dir="../datasets/04 argilla FinePersonas-Conversations-Email-Summaries"            
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# '/media/manjit/Project Drive/Email Summarizer/datasets/04 argilla FinePersonas-Conversations-Email-Summaries'
