# %% [markdown]
# # **Downloading datasets from `HuggingFace`**
# ---

# %% [markdown]
# ## **Dataset 1 - `koushik7198/Samsung-samsum_processed`**

# %%
# %pip install huggingface_hub

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="koushik7198/Samsung-samsum_processed",   
    repo_type="dataset",
    local_dir="../datasets/01 koushik7198 Samsung-samsum_processed"            
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# ...
# '/home/manjit/Desktop/Email-Summarizer/research/datasets/01 koushik7198 Samsung-samsum_processed'

# %% [markdown]
# ## **Dataset 2 - `argilla/FinePersonas-Conversations-Email-Summaries`**

# %%
snapshot_download(
    repo_id="argilla/FinePersonas-Conversations-Email-Summaries",   
    repo_type="dataset",
    local_dir="../datasets/02 argilla FinePersonas-Conversations-Email-Summaries"            
)
# Out:
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# '/home/manjit/Desktop/Email-Summarizer/research/datasets/02 argilla FinePersonas-Conversations-Email-Summaries'
